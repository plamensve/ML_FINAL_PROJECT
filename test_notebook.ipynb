# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('preprocessed_data/dataset.csv')
data
# Out:
#        age  gender  alcohol_consumption_per_week  \
# 0       58     0.0                             0
# 1       48     1.0                             1
# 2       60     0.0                             1
# 3       74     1.0                             0
# 4       46     0.0                             1
# ...    ...     ...                           ...
# 99995   46     0.0                             1
# 99996   41     1.0                             3
# 99997   57     1.0                             4
# 99998   47     1.0                             3
# 99999   52     1.0                             1
#
#        physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 0                                     215         5.7                  7.9
# 1                                     143         6.7                  6.5
# 2                                      57         6.4                 10.0
# ...

# %%
data['target'].shape
# Out:
# (100000,)

# %%
plt.scatter(
    data[data['target'] == 1]['sleep_hours_per_day'][:100],
    data[data['target'] == 1]['screen_time_hours_per_day'][:100],
    color='blue',
    label='Class 1'
)

plt.scatter(
    data[data['target'] == 0]['sleep_hours_per_day'][:100],
    data[data['target'] == 0]['screen_time_hours_per_day'][:100],
    color='red',
    label='Class 0'
)

plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data split
from sklearn.model_selection import train_test_split

# Models
from sklearn.ensemble import RandomForestClassifier

# Reports
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv('preprocessed_data/dataset.csv')
data
# Out:
#        age  gender  alcohol_consumption_per_week  \
# 0       58     0.0                             0
# 1       48     1.0                             1
# 2       60     0.0                             1
# 3       74     1.0                             0
# 4       46     0.0                             1
# ...    ...     ...                           ...
# 99995   46     0.0                             1
# 99996   41     1.0                             3
# 99997   57     1.0                             4
# 99998   47     1.0                             3
# 99999   52     1.0                             1
#
#        physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 0                                     215         5.7                  7.9
# 1                                     143         6.7                  6.5
# 2                                      57         6.4                 10.0
# ...

# %%
# Split dataset - 80K rows for model training and 20K for prediction and comparison
last_20_k = data.tail(20000)
data = data.iloc[:-20000]

# %%
X = data.drop(columns='target')
y = data['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# %%
model = RandomForestClassifier(
    n_estimators=50,
    max_depth=2
)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=50)

# %%
model.score(X_test, y_test)
# Out:
# 0.999625

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6412
#            1       1.00      1.00      1.00      9588
#
#     accuracy                           1.00     16000
#    macro avg       1.00      1.00      1.00     16000
# weighted avg       1.00      1.00      1.00     16000

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y, cv=5)
print(scores.mean())
# Out:
# 0.999475

# %%
last_20_k
# Out:
#        age  gender  alcohol_consumption_per_week  \
# 80000   61     1.0                             3
# 80001   45     1.0                             1
# 80002   49     1.0                             1
# 80003   47     0.0                             0
# 80004   58     0.0                             0
# ...    ...     ...                           ...
# 99995   46     0.0                             1
# 99996   41     1.0                             3
# 99997   57     1.0                             4
# 99998   47     1.0                             3
# 99999   52     1.0                             1
#
#        physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 80000                                 293         8.5                  6.9
# 80001                                  99         6.5                  7.1
# 80002                                 101         6.4                 10.0
# ...

# %%
# Split the dataset and separate the target column for later comparison with prediction results
X_last_20_k = last_20_k.drop(columns='target')
y_last_20_k = last_20_k['target']

# %%
prediction = model.predict(X_last_20_k)
prediction
# Out:
# array([0, 1, 1, ..., 0, 0, 0], shape=(20000,))

# %%
pred_dataframe = pd.DataFrame({
    'y_true': y_last_20_k,
    'y_pred': prediction
})

pred_dataframe.head()
# Out:
#        y_true  y_pred
# 80000       0       0
# 80001       1       1
# 80002       1       1
# 80003       0       0
# 80004       0       0

# %%
(pred_dataframe['y_true'] == pred_dataframe['y_pred']).mean()
# Out:
# np.float64(0.99965)

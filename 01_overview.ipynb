# %% [markdown]
# # Diabetes Health Indicators

# %% [markdown]
# #### Source link: https://www.kaggle.com/datasets/mohankrishnathalla/diabetes-health-indicators-dataset/data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import seaborn as sns

# %% [markdown]
# Here we present the `methodology` that will be used for data analysis — the `steps we will follow` to achieve the desired results.

# %%
plt.figure(figsize=(15, 10))
img = mpimg.imread("main_data_source/scientific_method_pic.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Reading and loading main dataset
data = pd.read_csv('main_data_source/diabetes_dataset.csv')
data
# Out:
#        age  gender ethnicity education_level  income_level employment_status  \
# 0       58    Male     Asian      Highschool  Lower-Middle          Employed
# 1       48  Female     White      Highschool        Middle          Employed
# 2       60    Male  Hispanic      Highschool        Middle        Unemployed
# 3       74  Female     Black      Highschool           Low           Retired
# 4       46    Male     White        Graduate        Middle           Retired
# ...    ...     ...       ...             ...           ...               ...
# 99995   46    Male     Other        Graduate  Upper-Middle        Unemployed
# 99996   41  Female     White        Graduate        Middle          Employed
# 99997   57  Female     Black       No formal  Upper-Middle          Employed
# 99998   47  Female     Black      Highschool  Lower-Middle           Retired
# 99999   52  Female     White    Postgraduate        Middle          Employed
#
# ...

# %%
# Checking the shape of the dataset
data.shape
# Out:
# (100000, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   age                                 100000 non-null  int64
#  1   gender                              100000 non-null  object
#  2   ethnicity                           100000 non-null  object
#  3   education_level                     100000 non-null  object
#  4   income_level                        100000 non-null  object
#  5   employment_status                   100000 non-null  object
#  6   smoking_status                      100000 non-null  object
#  7   alcohol_consumption_per_week        100000 non-null  int64
#  8   physical_activity_minutes_per_week  100000 non-null  int64
#  9   diet_score                          100000 non-null  float64
#  10  sleep_hours_per_day                 100000 non-null  float64
# ...

# %% [markdown]
# ### Checking for NaN values

# %%
columns = data.columns
for col in columns:
    if data[col].isna().sum() > 0:
        print(data[col].isna().sum())

# %% [markdown]
# ### Correlation matrix

# %%
corr = data.corr(
    method='spearman', # Using 'Spearman' method for non-normalized data
    numeric_only=True
)

plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Checking feature summary / descriptive stats and distribution

# %%
data[['age']].describe().T
# Out:
#         count      mean      std   min   25%   50%   75%   max
# age  100000.0  50.12041  15.6046  18.0  39.0  50.0  61.0  90.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['age'], edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
data[['physical_activity_minutes_per_week']].describe().T
# Out:
#                                        count       mean        std  min   25%  \
# physical_activity_minutes_per_week  100000.0  118.91164  84.409662  0.0  57.0
#
#                                       50%    75%    max
# physical_activity_minutes_per_week  100.0  160.0  833.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['physical_activity_minutes_per_week'], edgecolor='black')
plt.title('Physical Activity minutes per week')
plt.xlabel('Minutes per week')
plt.ylabel('Count')
plt.xticks(range(0, 1000, 100))
plt.show()

# %% [markdown]
# ### Diet Score
# Description:
# diet_score is a numerical indicator that reflects the overall quality of an individual’s diet based on the frequency and type of foods consumed.
#
# Values:
#
# Higher values → indicate a healthier, more balanced diet.
#
# Lower values → suggest a diet high in processed foods, sugars, or unhealthy fats.
#
# Example use:
# Commonly used as a feature in health or nutrition analysis to study correlations between dietary habits and health outcomes such as heart disease risk, cholesterol levels, or body mass index (BMI).

# %%
data[['diet_score']].describe().T
# Out:
#                count      mean       std  min  25%  50%  75%   max
# diet_score  100000.0  5.994787  1.780954  0.0  4.8  6.0  7.2  10.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['diet_score'], edgecolor='black')
plt.title('Diet Score Distribution')
plt.xlabel('Diet Score')
plt.ylabel('Count')
plt.show()

# %%
data[['sleep_hours_per_day']].describe().T
# Out:
#                         count      mean       std  min  25%  50%  75%   max
# sleep_hours_per_day  100000.0  6.997818  1.094622  3.0  6.3  7.0  7.7  10.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['diet_score'], edgecolor='black')
plt.title('Sleep hours per day Distribution')
plt.xlabel('Sleep hours per day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Body mass index [BMI]
# Description:
# bmi (Body Mass Index) is a numerical value that measures body fat based on weight and height. It is commonly used to assess whether a person’s weight is within a healthy range.
#
# $$
# BMI = \frac{weight\ (kg)}{height\ (m)^2}
# $$
#
# Example use:
# Frequently used in health data analysis and classification tasks to study relationships between body composition and risk factors such as heart disease, diabetes, or hypertension.

# %%
data[['bmi']].describe().T
# Out:
#         count       mean       std   min   25%   50%   75%   max
# bmi  100000.0  25.612653  3.586705  15.0  23.2  25.6  28.0  39.2

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['bmi'], edgecolor='black')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Systolic Blood Pressure
# Description:
# systolic_bp represents the systolic blood pressure, which is the pressure in the arteries when the heart contracts and pumps blood through the body.
#
# Values:
#
# Normal: < 120 mmHg
#
# Elevated: 120 – 129 mmHg
#
# High (Hypertension Stage 1): 130 – 139 mmHg
#
# High (Hypertension Stage 2): ≥ 140 mmHg
#
# Example use:
# Used as a key health indicator or feature in medical and health-related datasets to assess cardiovascular risk, predict hypertension, or analyze the impact of lifestyle factors such as diet and exercise.

# %%
data[['systolic_bp']].describe().T
# Out:
#                 count       mean        std   min    25%    50%    75%    max
# systolic_bp  100000.0  115.79961  14.284073  90.0  106.0  116.0  125.0  179.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['systolic_bp'], edgecolor='black')
plt.title('Systolic Blood pressure Distribution')
plt.xlabel('SBP')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Diastolic Blood pressure
# Description:
# diastolic_bp refers to the diastolic blood pressure, which measures the pressure in the arteries when the heart is resting between beats.
#
# Values:
#
# Normal: < 80 mmHg
#
# Elevated: 80 – 89 mmHg
#
# High (Hypertension Stage 2): ≥ 90 mmHg
#
# Example use:
# Commonly used as a clinical indicator in cardiovascular studies and health datasets to evaluate blood pressure levels, monitor hypertension, and analyze the relationship between lifestyle, stress, and heart health.

# %%
data[['diastolic_bp']].describe().T
# Out:
#                  count      mean      std   min   25%   50%   75%    max
# diastolic_bp  100000.0  75.23249  8.20425  50.0  70.0  75.0  81.0  110.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['diastolic_bp'], edgecolor='black')
plt.title('Diastolic Blood pressure Distribution')
plt.xlabel('DBP')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Heart Rate
# Description:
# heart_rate indicates the number of heartbeats per minute (bpm). It reflects how fast the heart is beating and is a key measure of cardiovascular function.
#
# Values:
#
# Normal (resting): 60 – 100 bpm
#
# Bradycardia: < 60 bpm
#
# Tachycardia: > 100 bpm
#
# Example use:
# Used as a vital sign or feature in health datasets to monitor cardiac activity, detect irregularities such as arrhythmia, and study correlations between heart rate, stress levels, and physical fitness.

# %%
data[['heart_rate']].describe().T
# Out:
#                count      mean       std   min   25%   50%   75%    max
# heart_rate  100000.0  69.63287  8.371954  40.0  64.0  70.0  75.0  105.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['heart_rate'], edgecolor='black')
plt.title('Heart rate Distribution')
plt.xlabel('Heart rate')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Cholesterol total
# Description:
# cholesterol_total represents the total amount of cholesterol in the blood, measured in milligrams per deciliter (mg/dL). It includes low-density lipoprotein (LDL), high-density lipoprotein (HDL), and a portion of triglycerides.
#
# Values:
#
# Desirable: < 200 mg/dL
#
# Borderline high: 200 – 239 mg/dL
#
# High: ≥ 240 mg/dL
#
# Example use:
# Serves as a key cardiovascular health indicator in medical datasets, often used in classification or regression tasks to assess heart disease risk, analyze lipid profiles, or study the effects of diet and lifestyle.

# %%
data[['cholesterol_total']].describe().T
# Out:
#                       count       mean        std    min    25%    50%    75%  \
# cholesterol_total  100000.0  185.97811  32.013005  100.0  164.0  186.0  208.0
#
#                      max
# cholesterol_total  318.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['cholesterol_total'], edgecolor='black')
plt.title('Cholesterol total Distribution')
plt.xlabel('Cholesterol [total]')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### HDL Cholesterol
# Description:
# hdl_cholesterol measures the “good” cholesterol, which helps remove excess cholesterol from the bloodstream and reduces the risk of heart disease.
#
# Values:
#
# Low (risk): < 40 mg/dL (men), < 50 mg/dL (women)
#
# Normal: 40–59 mg/dL
#
# High (protective): ≥ 60 mg/dL
#
# Example use:
# Used as a predictive feature in health and cardiovascular datasets to evaluate lipid balance, model heart disease risk, or study the impact of diet and physical activity on cholesterol levels.

# %%
data[['hdl_cholesterol']].describe().T
# Out:
#                     count      mean        std   min   25%   50%   75%   max
# hdl_cholesterol  100000.0  54.04279  10.267374  20.0  47.0  54.0  61.0  98.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['hdl_cholesterol'], edgecolor='black')
plt.title('HDL Cholesterol Distribution')
plt.xlabel('HDL Cholesterol')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### LDL Cholesterol
# Description:
# ldl_cholesterol represents the “bad” cholesterol, which can build up in the walls of arteries and increase the risk of atherosclerosis and heart disease.
#
# Values:
#
# Optimal: < 100 mg/dL
#
# Near optimal: 100 – 129 mg/dL
#
# Borderline high: 130 – 159 mg/dL
#
# High: 160 – 189 mg/dL
#
# Very high: ≥ 190 mg/dL
#
# Example use:
# Commonly used as a health indicator in cardiovascular and metabolic datasets to assess the risk of heart disease, predict lipid disorders, and analyze relationships between diet, lifestyle, and cholesterol levels.

# %%
data[['ldl_cholesterol']].describe().T
# Out:
#                     count       mean        std   min   25%    50%    75%  \
# ldl_cholesterol  100000.0  103.00043  33.390256  50.0  78.0  102.0  126.0
#
#                    max
# ldl_cholesterol  263.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['ldl_cholesterol'], edgecolor='black')
plt.title('LDL Cholesterol Distribution')
plt.xlabel('LDL Cholesterol')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Triglycerides
# Description:
# triglycerides indicate the amount of triglycerides (a type of fat) in the blood, measured in milligrams per deciliter (mg/dL). High levels can contribute to the hardening or thickening of artery walls, increasing cardiovascular risk.
#
# Values:
#
# Normal: < 150 mg/dL
#
# Borderline high: 150 – 199 mg/dL
#
# High: 200 – 499 mg/dL
#
# Very high: ≥ 500 mg/dL
#
# Example use:
# Used as a key biochemical feature in health and metabolic datasets to study cardiovascular risk, lipid metabolism, and the impact of diet, obesity, or diabetes on blood fat levels.

# %%
data[['triglycerides']].describe().T
# Out:
#                   count       mean        std   min   25%    50%    75%    max
# triglycerides  100000.0  121.46265  43.372619  30.0  91.0  121.0  151.0  344.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['triglycerides'], edgecolor='black')
plt.title('Triglycerides Distribution')
plt.xlabel('Triglycerides')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Glucose fasting
# Description:
# glucose_fasting measures the level of glucose (sugar) in the blood after fasting for at least 8 hours, expressed in milligrams per deciliter (mg/dL). It is an essential indicator for evaluating blood sugar control and diagnosing diabetes.
#
# Values:
#
# Normal: < 100 mg/dL
#
# Prediabetes: 100 – 125 mg/dL
#
# Diabetes: ≥ 126 mg/dL
#
# Example use:
# Commonly used in medical and metabolic datasets for classification or regression tasks to predict diabetes risk, assess insulin resistance, and study the relationship between glucose levels, diet, and lifestyle.

# %%
data[['glucose_fasting']].describe().T
# Out:
#                     count       mean       std   min    25%    50%    75%  \
# glucose_fasting  100000.0  111.11712  13.59561  60.0  102.0  111.0  120.0
#
#                    max
# glucose_fasting  172.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['glucose_fasting'], edgecolor='black')
plt.title('Glucose Fasting Distribution')
plt.xlabel('Glucose Fasting')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Glucose postprandial
# Description:
# glucose_postprandial represents the blood glucose level measured after eating (typically 2 hours after a meal), expressed in milligrams per deciliter (mg/dL). It reflects how the body manages sugar intake and insulin response after food consumption.
#
# Values:
#
# Normal: < 140 mg/dL
#
# Prediabetes: 140 – 199 mg/dL
#
# Diabetes: ≥ 200 mg/dL
#
# Example use:
# Used in metabolic and endocrinology datasets to evaluate glucose tolerance, predict diabetes onset, and analyze post-meal blood sugar fluctuations in relation to diet and insulin sensitivity.

# %%
data[['glucose_postprandial']].describe().T
# Out:
#                          count       mean        std   min    25%    50%  \
# glucose_postprandial  100000.0  160.03505  30.935472  70.0  139.0  160.0
#
#                         75%    max
# glucose_postprandial  181.0  287.0

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['glucose_postprandial'], edgecolor='black')
plt.title('Glucose Postprandial Distribution')
plt.xlabel('Glucose Postprandial')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Insulin level
# Description:
# insulin_level indicates the amount of insulin present in the blood, measured in micro–units per milliliter (µU/mL). It helps assess how effectively the body regulates blood glucose and responds to insulin.
#
# Values:
#
# Normal (fasting): 2 – 25 µU/mL
#
# Elevated: > 25 µU/mL (may indicate insulin resistance or hyperinsulinemia)
#
# Example use:
# Commonly used in metabolic and diabetes-related datasets to study insulin resistance, classify metabolic syndrome, or predict type 2 diabetes risk based on glucose–insulin interaction patterns.

# %%
data[['insulin_level']].describe().T
# Out:
#                   count      mean      std  min   25%   50%    75%    max
# insulin_level  100000.0  9.061242  4.95406  2.0  5.09  8.79  12.45  32.22

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['insulin_level'], edgecolor='black')
plt.title('Insulin level Distribution')
plt.xlabel('Insulin level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Hemoglobin A1c
# Description:
# hba1c measures the average blood glucose level over the past 2–3 months, expressed as a percentage. It reflects the proportion of hemoglobin that has glucose attached to it and is a key indicator of long-term blood sugar control.
#
# Values:
#
# Normal: < 5.7%
#
# Prediabetes: 5.7% – 6.4%
#
# Diabetes: ≥ 6.5%
#
# Example use:
# Used extensively in diabetes monitoring and prediction models to assess glycemic control, identify chronic hyperglycemia, and evaluate the effectiveness of treatment or lifestyle interventions.

# %%
data[['hba1c']].describe().T
# Out:
#           count      mean       std  min   25%   50%   75%  max
# hba1c  100000.0  6.520776  0.813921  4.0  5.97  6.52  7.07  9.8

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['hba1c'], edgecolor='black')
plt.title('hba1c Distribution')
plt.xlabel('hba1c')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Diabetes risk score
# Description:
# diabetes_risk_score is a composite indicator that estimates an individual’s likelihood of developing diabetes based on multiple health and lifestyle factors such as age, BMI, blood pressure, glucose, cholesterol, and family history.
#
# Values:
#
# Low risk: 0 – 25
#
# Moderate risk: 26 – 50
#
# High risk: 51 – 75
#
# Very high risk: 76 – 100
# (ranges may vary depending on the scoring system used)
#
# Example use:
# Applied in predictive health models and epidemiological studies to classify patients by diabetes risk level, support early intervention, and analyze the contribution of metabolic and behavioral factors to diabetes development.

# %%
data[['diabetes_risk_score']].describe().T
# Out:
#                         count       mean       std  min   25%   50%   75%  \
# diabetes_risk_score  100000.0  30.222362  9.061505  2.7  23.8  29.0  35.6
#
#                       max
# diabetes_risk_score  67.2

# %%
plt.figure(figsize=(7, 5))
plt.hist(data['diabetes_risk_score'], edgecolor='black')
plt.title('Diabetes risk score')
plt.xlabel('Diabetes risk score')
plt.ylabel('Count')
plt.show()
